# %%
# %%sql
# -- ==============================================================
# -- CREATE TABLE: LH_Gold_layer.audit.source_metadata_config
# -- ==============================================================
#
# CREATE TABLE LH_Gold_layer.audit.source_metadata_config (
#     ROW_ID                      BIGINT,
#     SOURCE_TYPE                 STRING,
#     FILE_NAME                   STRING,
#     FILE_EXTENSION              STRING,
#     SOURCE_CONNECTION_NAME      STRING,
#     SOURCE_SERVER               STRING,
#     SOURCE_DATABASE             STRING,
#     SOURCE_SCHEMA               STRING,
#     SOURCE_TABLE                STRING,
#     TARGET_TABLE                STRING,
#     LAYER                       STRING,
#     KEY_COLUMNS                 STRING,
#     NON_KEY_COLUMNS             STRING,
#     INCREMENTAL_COLUMN_IDENTIFIER STRING,
#     PROCEDURE_NAME              STRING,
#     NOTEBOOK_ID                 STRING,
#     NOTEBOOK_NAME               STRING,
#     EMAIL_JSON                  STRING,
#     TRIGGER_SCHEDULE            STRING,
#     FREQUENCY                   STRING,
#     LOAD_TYPE                   STRING,
#     LAST_MODIFIED_TS            TIMESTAMP,
#     ISACTIVE                    INT,
#     SCD_FLAG                    STRING,
#     TABLE_TYPE                  STRING,
#     OPERATION_TYPE              STRING,
#     STOP_FUTURE_PROCESSING      INT,
#     PRIORITY_DEPENDANCY         STRING,
#     PRIORITY                    INT,
#     IS_LOADED_STATUS_BRONZE     INT,
#     SYSTEM_PREFIX               STRING
# )
# USING DELTA
# Out:
# StatementMeta(, eb721264-8ad6-4273-bc67-7d6951597516, 24, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# -- ==============================================================
# -- SOURCE_METADATA_CONFIG INSERT
# -- Target: LH_Gold_layer.audit.source_metadata_config
# -- Source: AdventureWorks Product schema
# -- ==============================================================
#
# INSERT INTO LH_Gold_layer.audit.source_metadata_config (
#     ROW_ID,
#     SOURCE_TYPE,
#     FILE_NAME,
#     FILE_EXTENSION,
#     SOURCE_CONNECTION_NAME,
#     SOURCE_SERVER,
#     SOURCE_DATABASE,
#     SOURCE_SCHEMA,
#     SOURCE_TABLE,
#     TARGET_TABLE,
#     LAYER,
#     KEY_COLUMNS,
#     NON_KEY_COLUMNS,
#     INCREMENTAL_COLUMN_IDENTIFIER,
#     PROCEDURE_NAME,
#     NOTEBOOK_ID,
#     NOTEBOOK_NAME,
#     EMAIL_JSON,
#     TRIGGER_SCHEDULE,
#     FREQUENCY,
#     LOAD_TYPE,
#     LAST_MODIFIED_TS,
#     ISACTIVE,
#     SCD_FLAG,
#     TABLE_TYPE,
#     OPERATION_TYPE,
#     STOP_FUTURE_PROCESSING,
#     PRIORITY_DEPENDANCY,
#     PRIORITY,
#     IS_LOADED_STATUS_BRONZE,
#     SYSTEM_PREFIX
# )
# VALUES
# -- ──────────────────────────────────────────────
# -- MASTER tables (FULL load, SCD1)
# -- ──────────────────────────────────────────────
# (1,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'Product',                              'Product',                              'GOLD', 'ProductID', NULL, NULL, NULL, NULL, 'nb_load_product',                              NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 1,  0, 'AW'),
# (2,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductCategory',                      'ProductCategory',                      'GOLD', 'ProductCategoryID', NULL, NULL, NULL, NULL, 'nb_load_productcategory',              NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 2,  0, 'AW'),
# (3,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductSubcategory',                   'ProductSubcategory',                   'GOLD', 'ProductSubcategoryID', NULL, NULL, NULL, NULL, 'nb_load_productsubcategory',          NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 3,  0, 'AW'),
# (4,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductDescription',                   'ProductDescription',                   'GOLD', 'ProductDescriptionID', NULL, NULL, NULL, NULL, 'nb_load_productdescription',          NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 4,  0, 'AW'),
# (5,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductModel',                         'ProductModel',                         'GOLD', 'ProductModelID', NULL, NULL, NULL, NULL, 'nb_load_productmodel',                  NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 5,  0, 'AW'),
# (6,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductPhoto',                         'ProductPhoto',                         'GOLD', 'ProductPhotoID', NULL, NULL, NULL, NULL, 'nb_load_productphoto',                  NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 6,  0, 'AW'),
# (7,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductDocument',                      'ProductDocument',                      'GOLD', 'ProductID', NULL, NULL, NULL, NULL, 'nb_load_productdocument',               NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 7,  0, 'AW'),
# (8,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductModelIllustration',             'ProductModelIllustration',             'GOLD', 'ProductModelID,IllustrationID', NULL, NULL, NULL, NULL, 'nb_load_productmodelillustration', NULL, NULL, 'DAILY', 'FULL', current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 8,  0, 'AW'),
# (9,  'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductModelProductDescriptionCulture','ProductModelProductDescriptionCulture','GOLD', 'ProductModelID,ProductDescriptionID,CultureID', NULL, NULL, NULL, NULL, 'nb_load_productmodelproductdescriptionculture', NULL, NULL, 'DAILY', 'FULL', current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 9,  0, 'AW'),
# (10, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductProductPhoto',                  'ProductProductPhoto',                  'GOLD', 'ProductID,ProductPhotoID', NULL, NULL, NULL, NULL, 'nb_load_productproductphoto',   NULL, NULL, 'DAILY', 'FULL',        current_timestamp(), 1, 'SCD1', 'MASTER', 'UPSERT', 0, NULL, 10, 0, 'AW'),
#
# -- ──────────────────────────────────────────────
# -- FACT tables (INCREMENTAL load, SCD1)
# -- ──────────────────────────────────────────────
# (11, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductInventory',    'ProductInventory',    'GOLD', 'ProductID,LocationID',              NULL, 'ModifiedDate', NULL, NULL, 'nb_load_productinventory',    NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD1', 'FACT', 'UPSERT', 0, NULL, 11, 0, 'AW'),
# (12, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductReview',       'ProductReview',       'GOLD', 'ProductReviewID',                   NULL, 'ModifiedDate', NULL, NULL, 'nb_load_productreview',       NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD1', 'FACT', 'UPSERT', 0, NULL, 12, 0, 'AW'),
# (13, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Purchasing', 'ProductVendor',       'ProductVendor',       'GOLD', 'ProductID,BusinessEntityID',         NULL, 'ModifiedDate', NULL, NULL, 'nb_load_productvendor',       NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD1', 'FACT', 'UPSERT', 0, NULL, 13, 0, 'AW'),
# (14, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Purchasing', 'PurchaseOrderHeader', 'PurchaseOrderHeader', 'GOLD', 'PurchaseOrderID',                   NULL, 'ModifiedDate', NULL, NULL, 'nb_load_purchaseorderheader', NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD1', 'FACT', 'UPSERT', 0, NULL, 14, 0, 'AW'),
# (15, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Purchasing', 'PurchaseOrderDetail', 'PurchaseOrderDetail', 'GOLD', 'PurchaseOrderID,PurchaseOrderDetailID', NULL, 'ModifiedDate', NULL, NULL, 'nb_load_purchaseorderdetail', NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD1', 'FACT', 'UPSERT', 0, NULL, 15, 0, 'AW'),
#
# -- ──────────────────────────────────────────────
# -- FACT tables (INCREMENTAL load, SCD2)
# -- ──────────────────────────────────────────────
# (16, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductCostHistory',      'ProductCostHistory',      'GOLD', 'ProductID,StartDate',  NULL, 'ModifiedDate', NULL, NULL, 'nb_load_productcosthistory',      NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD2', 'FACT', 'UPSERT', 0, NULL, 16, 0, 'AW'),
# (17, 'DATABASE', NULL, NULL, 'SRC_ADVENTUREWORKS', NULL, 'AdventureWorks', 'Production', 'ProductListPriceHistory', 'ProductListPriceHistory', 'GOLD', 'ProductID,StartDate',  NULL, 'ModifiedDate', NULL, NULL, 'nb_load_productlistpricehistory', NULL, NULL, 'DAILY', 'INCREMENTAL', current_timestamp(), 1, 'SCD2', 'FACT', 'UPSERT', 0, NULL, 17, 0, 'AW');
# Out:
# StatementMeta(, eb721264-8ad6-4273-bc67-7d6951597516, 27, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>
